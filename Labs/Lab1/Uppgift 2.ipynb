# %% [markdown]
# # Uppgift 2

# %%
import pandas as pd
import plotly_express as px
import matplotlib.pyplot as plt

vaccin = pd.read_excel("Data/vaccin.xlsx", sheet_name="Vaccinerade kommun och ålder")
vaccin.head(20)
# Out:
#     Län        Län_namn  Kommun     Kommun_namn           Ålder  Befolkning  \
# 0     1  Stockholms län     114  Upplands Väsby           12-15        2422
# 1     1  Stockholms län     114  Upplands Väsby           16-17        1203
# 2     1  Stockholms län     114  Upplands Väsby           18-29        6692
# 3     1  Stockholms län     114  Upplands Väsby           30-39        7332
# 4     1  Stockholms län     114  Upplands Väsby           40-49        6946
# 5     1  Stockholms län     114  Upplands Väsby           50-59        6332
# 6     1  Stockholms län     114  Upplands Väsby           60-69        4258
# 7     1  Stockholms län     114  Upplands Väsby           70-79        3987
# 8     1  Stockholms län     114  Upplands Väsby           80-89        1934
# 9     1  Stockholms län     114  Upplands Väsby  90 eller äldre         337
# 10    1  Stockholms län     115      Vallentuna           12-15        2109
# 11    1  Stockholms län     115      Vallentuna           16-17        1014
# 12    1  Stockholms län     115      Vallentuna           18-29        4210
# 13    1  Stockholms län     115      Vallentuna           30-39        4286
# 14    1  Stockholms län     115      Vallentuna           40-49        5277
# 15    1  Stockholms län     115      Vallentuna           50-59        4996
# 16    1  Stockholms län     115      Vallentuna           60-69        3215
# 17    1  Stockholms län     115      Vallentuna           70-79        2651
# 18    1  Stockholms län     115      Vallentuna           80-89        1412
# 19    1  Stockholms län     115      Vallentuna  90 eller äldre         242
#
#     Antal minst 1 dos  Antal minst 2 doser  Antal 3 doser  Antal 4 doser  \
# 0                1206                 1046            NaN            NaN
# 1                 839                  755            NaN            NaN
# 2                4887                 4469         1959.0            NaN
# 3                5542                 5240         2878.0            NaN
# 4                5592                 5429         3719.0            NaN
# 5                5644                 5558         4535.0            NaN
# 6                3829                 3786         3335.0            NaN
# 7                3786                 3758         3584.0         3051.0
# 8                1859                 1856         1802.0         1617.0
# 9                 330                  327          319.0          277.0
# 10               1196                 1069            NaN            NaN
# 11                841                  768            NaN            NaN
# 12               3374                 3189         1651.0            NaN
# 13               3602                 3499         2266.0            NaN
# 14               4701                 4604         3604.0            NaN
# 15               4561                 4505         3850.0            NaN
# 16               2990                 2967         2690.0            NaN
# 17               2555                 2542         2461.0         2187.0
# 18               1375                 1371         1327.0         1197.0
# 19                230                  230          223.0          195.0
#
#     Andel minst 1 dos  Andel minst 2 doser  Andel 3 doser  Andel 4 doser
# 0            0.497936             0.431874            NaN            NaN
# 1            0.697423             0.627598            NaN            NaN
# 2            0.730275             0.667812       0.292738            NaN
# 3            0.755865             0.714675       0.392526            NaN
# 4            0.805068             0.781601       0.535416            NaN
# 5            0.891346             0.877764       0.716203            NaN
# 6            0.899248             0.889150       0.783232            NaN
# 7            0.949586             0.942563       0.898921       0.765237
# 8            0.961220             0.959669       0.931748       0.836091
# 9            0.979228             0.970326       0.946588       0.821958
# 10           0.567093             0.506875            NaN            NaN
# 11           0.829389             0.757396            NaN            NaN
# 12           0.801425             0.757482       0.392162            NaN
# 13           0.840411             0.816379       0.528698            NaN
# 14           0.890847             0.872465       0.682964            NaN
# 15           0.912930             0.901721       0.770616            NaN
# 16           0.930016             0.922862       0.836703            NaN
# 17           0.963787             0.958883       0.928329       0.824972
# 18           0.973796             0.970963       0.939802       0.847734
# 19           0.950413             0.950413       0.921488       0.805785

# %%
len(vaccin["Län_namn"].unique())
# 2a) svar: 21
# Out:
# 21

# %%
len(vaccin["Kommun_namn"].unique())
# 2b) svar: 290
# Out:
# 290

# %%
vaccin["Befolkning"].sum()
# 2c svar: 9092790
# Out:
# 9092790

# %%
vaccin[(vaccin["Ålder"] == "12-15") | (vaccin["Ålder"] == "16-17")]["Befolkning"].sum()
# 2d) svar: 745370
# Out:
# 745370

# %%
px.histogram(vaccin, x = "Ålder", y="Befolkning")
# 2e)

# %%
""" px.histogram(
    vaccin,
    x="Län_namn",
    y=["Andel minst 1 dos", "Andel minst 2 doser", "Andel 3 doser"],
    barmode="group",
    title="Vaccineringsgrad i Sveriges län",
) """
# TODO Räkna om denna helt. Nu summerar den antagligen de procentuella värdena.
# Out:
# ' px.histogram(\n    vaccin,\n    x="Län_namn",\n    y=["Andel minst 1 dos", "Andel minst 2 doser", "Andel 3 doser"],\n    barmode="group",\n    title="Vaccineringsgrad i Sveriges län",\n) '

# %%
vaccin.head()
# Out:
#    Län        Län_namn  Kommun     Kommun_namn  Ålder  Befolkning  \
# 0    1  Stockholms län     114  Upplands Väsby  12-15        2422
# 1    1  Stockholms län     114  Upplands Väsby  16-17        1203
# 2    1  Stockholms län     114  Upplands Väsby  18-29        6692
# 3    1  Stockholms län     114  Upplands Väsby  30-39        7332
# 4    1  Stockholms län     114  Upplands Väsby  40-49        6946
#
#    Antal minst 1 dos  Antal minst 2 doser  Antal 3 doser  Antal 4 doser  \
# 0               1206                 1046            NaN            NaN
# 1                839                  755            NaN            NaN
# 2               4887                 4469         1959.0            NaN
# 3               5542                 5240         2878.0            NaN
# 4               5592                 5429         3719.0            NaN
#
#    Andel minst 1 dos  Andel minst 2 doser  Andel 3 doser  Andel 4 doser
# 0           0.497936             0.431874            NaN            NaN
# 1           0.697423             0.627598            NaN            NaN
# 2           0.730275             0.667812       0.292738            NaN
# 3           0.755865             0.714675       0.392526            NaN
# 4           0.805068             0.781601       0.535416            NaN

# %%
vaccin_lan = vaccin.groupby("Län")
fig = px.bar(
    y=[
        # calculating share of people that have taken a certain number of vaccines
        vaccin_lan["Antal minst 1 dos"].sum() / vaccin_lan["Befolkning"].sum(),
        vaccin_lan["Antal minst 2 doser"].sum() / vaccin_lan["Befolkning"].sum(),
        vaccin_lan["Antal 3 doser"].sum() / vaccin_lan["Befolkning"].sum(),
    ],
    labels={"value": "Andel vaccinerade", "x": "Län"},
    title="Andel vaccinerade uppdelade på län",
    barmode="group",
    x=vaccin.Län_namn.unique(),
)
# changing variable names
newnames = {
    "wide_variable_0": "Minst 1 dos",
    "wide_variable_1": "Minst 2 doser",
    "wide_variable_2": "Minst 3 doser",
}
fig.for_each_trace(
    lambda t: t.update(
        name=newnames[t.name],
        legendgroup=newnames[t.name],
        hovertemplate=t.hovertemplate.replace(t.name, newnames[t.name]),
    )
)

fig.show()
# 2f)

# %%
type(vaccin_lan["Antal minst 1 dos"].sum() / vaccin_lan["Befolkning"].sum())
# Out:
# pandas.core.series.Series

# %%
vaccin_vg_sthlm = vaccin[(vaccin["Län_namn"] == "Västra Götalands län") | (vaccin["Län_namn"] == "Stockholms län")]
vaccin_vg_sthlm_grouped = vaccin_vg_sthlm.groupby("Län")


fig = px.bar(
    y=[
        # calculating share of people that have taken a certain number of vaccines
        vaccin_vg_sthlm_grouped["Antal minst 1 dos"].sum() / vaccin_vg_sthlm_grouped["Befolkning"].sum(),
        vaccin_vg_sthlm_grouped["Antal minst 2 doser"].sum() / vaccin_vg_sthlm_grouped["Befolkning"].sum(),
        vaccin_vg_sthlm_grouped["Antal 3 doser"].sum() / vaccin_vg_sthlm_grouped["Befolkning"].sum(),
        vaccin_vg_sthlm_grouped["Antal 4 doser"].sum() / vaccin_vg_sthlm_grouped["Befolkning"].sum(),
    ],
    labels={"value": "Andel vaccinerade", "x": "Län"},
    title="Andel vaccinerade uppdelade på län",
    barmode="group",
    x=vaccin_vg_sthlm.Län_namn.unique(),
)
# changing variable names
newnames = {
    "wide_variable_0": "Minst 1 dos",
    "wide_variable_1": "Minst 2 doser",
    "wide_variable_2": "Minst 3 doser",
    "wide_variable_3": "Minst 4 doser",
}
fig.for_each_trace(
    lambda t: t.update(
        name=newnames[t.name],
        legendgroup=newnames[t.name],
        hovertemplate=t.hovertemplate.replace(t.name, newnames[t.name]),
    )
)

fig.show()
# 2g)
#TODO: gör transpose på hela skiten

# %%
vaccin_vg_sthlm = vaccin[(vaccin["Län_namn"] == "Västra Götalands län") | (vaccin["Län_namn"] == "Stockholms län")]
vaccin_vg_sthlm_grouped = vaccin_vg_sthlm.groupby("Län")


fig = px.bar(
    y=[
        # calculating share of people that have taken a certain number of vaccines
        vaccin_vg_sthlm_grouped["Antal minst 1 dos"].sum() / vaccin_vg_sthlm_grouped["Befolkning"].sum(),
        vaccin_vg_sthlm_grouped["Antal minst 2 doser"].sum() / vaccin_vg_sthlm_grouped["Befolkning"].sum(),
    ],
    labels={"value": "Andel vaccinerade", "x": "Län"},
    title="Andel vaccinerade uppdelade på län",
    barmode="group",
    x=["Antal minst en dos", "Antal minst två doser", "Antal 3 doser", "Antal 4 doser"],
)
# changing variable names
newnames = {
    "wide_variable_0": "Minst 1 dos",
    "wide_variable_1": "Minst 2 doser",
}
fig.for_each_trace(
    lambda t: t.update(
        name=newnames[t.name],
        legendgroup=newnames[t.name],
        hovertemplate=t.hovertemplate.replace(t.name, newnames[t.name]),
    )
)

fig.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In [39], line 5
#       1 vaccin_vg_sthlm = vaccin[(vaccin["Län_namn"] == "Västra Götalands län") | (vaccin["Län_namn"] == "Stockholms län")]
#       2 vaccin_vg_sthlm_grouped = vaccin_vg_sthlm.groupby("Län")
# ----> 5 fig = px.bar(
#       6     y=[
#       7         # calculating share of people that have taken a certain number of vaccines
#       8         vaccin_vg_sthlm_grouped["Antal minst 1 dos"].sum() / vaccin_vg_sthlm_grouped["Befolkning"].sum(),
#       9         vaccin_vg_sthlm_grouped["Antal minst 2 doser"].sum() / vaccin_vg_sthlm_grouped["Befolkning"].sum(),
#      10     ],
#      11     labels={"value": "Andel vaccinerade", "x": "Län"},
#      12     title="Andel vaccinerade uppdelade på län",
#      13     barmode="group",
#      14     x=["Antal minst en dos", "Antal minst två doser", "Antal 3 doser", "Antal 4 doser"],
#      15 )
#      16 # changing variable names
#      17 newnames = {
#      18     "wide_variable_0": "Minst 1 dos",
#      19     "wide_variable_1": "Minst 2 doser",
#      20 }
#
# File c:\Users\hakan\.virtualenvs\Databehandling-Hakan-Akerblom-NMyM-zFH\lib\site-packages\plotly\express\_chart_types.py:373, in bar(data_frame, x, y, color, pattern_shape, facet_row, facet_col, facet_col_wrap, facet_row_spacing, facet_col_spacing, hover_name, hover_data, custom_data, text, base, error_x, error_x_minus, error_y, error_y_minus, animation_frame, animation_group, category_orders, labels, color_discrete_sequence, color_discrete_map, color_continuous_scale, pattern_shape_sequence, pattern_shape_map, range_color, color_continuous_midpoint, opacity, orientation, barmode, log_x, log_y, range_x, range_y, text_auto, title, template, width, height)
#     325 def bar(
#     326     data_frame=None,
#     327     x=None,
#    (...)
#     367     height=None,
#     368 ) -> go.Figure:
#     369     """
#     370     In a bar plot, each row of `data_frame` is represented as a rectangular
#     371     mark.
#     372     """
# --> 373     return make_figure(
#     374         args=locals(),
#     375         constructor=go.Bar,
#     376         trace_patch=dict(textposition="auto"),
#     377         layout_patch=dict(barmode=barmode),
#     378     )
#
# File c:\Users\hakan\.virtualenvs\Databehandling-Hakan-Akerblom-NMyM-zFH\lib\site-packages\plotly\express\_core.py:1990, in make_figure(args, constructor, trace_patch, layout_patch)
#    1987 layout_patch = layout_patch or {}
#    1988 apply_default_cascade(args)
# -> 1990 args = build_dataframe(args, constructor)
#    1991 if constructor in [go.Treemap, go.Sunburst, go.Icicle] and args["path"] is not None:
#    1992     args = process_dataframe_hierarchy(args)
#
# File c:\Users\hakan\.virtualenvs\Databehandling-Hakan-Akerblom-NMyM-zFH\lib\site-packages\plotly\express\_core.py:1405, in build_dataframe(args, constructor)
#    1402     args["color"] = None
#    1403 # now that things have been prepped, we do the systematic rewriting of `args`
# -> 1405 df_output, wide_id_vars = process_args_into_dataframe(
#    1406     args, wide_mode, var_name, value_name
#    1407 )
#    1409 # now that `df_output` exists and `args` contains only references, we complete
#    1410 # the special-case and wide-mode handling by further rewriting args and/or mutating
#    1411 # df_output
#    1413 count_name = _escape_col_name(df_output, "count", [var_name, value_name])
#
# File c:\Users\hakan\.virtualenvs\Databehandling-Hakan-Akerblom-NMyM-zFH\lib\site-packages\plotly\express\_core.py:1245, in process_args_into_dataframe(args, wide_mode, var_name, value_name)
#    1242         col_name = _check_name_not_reserved(field, reserved_names)
#    1244     if length and len(argument) != length:
# -> 1245         raise ValueError(
#    1246             "All arguments should have the same length. "
#    1247             "The length of argument `%s` is %d, whereas the "
#    1248             "length of  previously-processed arguments %s is %d"
#    1249             % (field, len(argument), str(list(df_output.columns)), length)
#    1250         )
#    1251     df_output[str(col_name)] = to_unindexed_series(argument)
#    1253 # Finally, update argument with column name now that column exists
#
# ValueError: All arguments should have the same length. The length of argument `wide_variable_0` is 2, whereas the length of  previously-processed arguments ['x'] is 4

# %%
import plotly.graph_objects as go

# ugly radar diagram
vaccin_vg = vaccin[vaccin["Län_namn"] == "Västra Götalands län"]
vaccin_sthlm = vaccin[vaccin["Län_namn"] == "Stockholms län"]

vg_1 = vaccin_vg["Antal minst 1 dos"].sum() / vaccin_vg["Befolkning"].sum()
vg_2 = vaccin_vg["Antal minst 2 doser"].sum() / vaccin_vg["Befolkning"].sum()
vg_3 = vaccin_vg["Antal 3 doser"].sum() / vaccin_vg["Befolkning"].sum()
vg_4 = vaccin_vg["Antal 4 doser"].sum() / vaccin_vg["Befolkning"].sum()

sthlm_1 = vaccin_sthlm["Antal minst 1 dos"].sum() / vaccin_sthlm["Befolkning"].sum()
sthlm_2 = vaccin_sthlm["Antal minst 2 doser"].sum() / vaccin_sthlm["Befolkning"].sum()
sthlm_3 = vaccin_sthlm["Antal 3 doser"].sum() / vaccin_sthlm["Befolkning"].sum()
sthlm_4 = vaccin_sthlm["Antal 4 doser"].sum() / vaccin_sthlm["Befolkning"].sum()

categories = ["Minst 1 dos", "Minst 2 doser", "Minst 3 doser", "4 doser"]

fig = go.Figure()

fig.add_trace(
    go.Scatterpolar(
        r=[vg_1, vg_2, vg_3, vg_4],
        theta=categories,
        fill="toself",
        name="vg",
    )
)
fig.add_trace(
    go.Scatterpolar(
        r=[sthlm_1, sthlm_2, sthlm_3, sthlm_4],
        theta=categories,
        fill="toself",
        name="vg",
    )
)

fig.update_layout(
    polar=dict(radialaxis=dict(visible=True, range=[0, 1])), showlegend=False
)

fig.show()

# %%
a1 = vaccin_lan["Antal minst 1 dos"].sum() / vaccin_lan["Befolkning"].sum()
a2 = vaccin_lan["Antal minst 2 doser"].sum() / vaccin_lan["Befolkning"].sum()
a3 = vaccin_lan["Antal 3 doser"].sum() / vaccin_lan["Befolkning"].sum()
a4 = vaccin_lan["Antal 4 doser"].sum() / vaccin_lan["Befolkning"].sum()
f = pd.DataFrame()
f["Minst 1 dos"] = a1
f["Minst 2 doser"] = a2
f["Minst 3 doser"] = a3
f["Minst 4 doser"] = a4
f.head()
# Out:
#      Minst 1 dos  Minst 2 doser  Minst 3 doser  Minst 4 doser
# Län
# 1       0.831199       0.801076       0.569462       0.112667
# 3       0.895379       0.875748       0.657227       0.148082
# 4       0.868316       0.846110       0.613381       0.173787
# 5       0.883365       0.870943       0.659068       0.161982
# 6       0.866411       0.851620       0.628596       0.161961
